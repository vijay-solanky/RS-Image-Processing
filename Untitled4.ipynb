# %% [markdown]
# <a href="https://colab.research.google.com/github/vijay-solanky/RS-Image-Processing/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Mount your Google Drive here
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/gerasimosmichalitsianos/pansharpen

# %%
# !pip install pansharpen/ --upgrade

# %%
# !pansharpen --panchromatic '/content/drive/My Drive/Colab Notebooks/L8_Fusion/L8_panff.tif' --multispectral '/content/drive/My Drive/Colab Notebooks/L8_Fusion/L8_MSf.tif'

# %%
# !pip install rasterio

# %%
import rasterio
from rasterio.plot import show
from rasterio.plot import show_hist

pan= rasterio.open(r'/content/drive/My Drive/Colab Notebooks/L8_Fusion/L8_panff.tif')
ms = rasterio.open(r'/content/drive/My Drive/Colab Notebooks/L8_Fusion/L8_MSf.tif')
wvlt_fused= rasterio.open(r'/content/drive/My Drive/Colab Notebooks/L8_Fusion/L8_MSf_panSharpenedWAVELET.tif')
show(pan)
show((ms, 3), cmap='terrain')

show_hist(pan, bins=100, lw=0.0, stacked=False, alpha=0.3, histtype='stepfilled', title=" PAN Histogram")
 
show_hist(ms, bins=100, lw=0.0, stacked=False, alpha=0.3, histtype='stepfilled', title=" MS Histogram")

show_hist(ms, bins=100, lw=0.0, stacked=False, alpha=0.3, histtype='stepfilled', title=" Wavelet Fusion Histogram")
